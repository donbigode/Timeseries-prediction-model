# %%
import pandas as pd
import openpyxl
import numpy as np
import os
import glob2
import glob
import random
import sklearn
import ntpath
import json
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from nltk.test.portuguese_en_fixt import setup_module
import nltk
from contextlib import nullcontext
import unicodedata
import plotly
import read_file_exec as rfe

# %% [markdown]
# ## Puxada dos dados modelados do processo de extração

# %%
modelo_inventario = rfe.read_file('etl_results/tempo_em_estoque.xlsx').get_df()
modelo_transac_prod = rfe.read_file('etl_results/transacoes_produto_tratado_final.xlsx').get_df()

# %% [markdown]
# ## Dados de Inventário

# %%
modelo_inventario
# Out:
#        codigo                                 descricao  categoria  \
# 0     7100692                APLIQUE - APM4 -053 NOIVOS  papelaria
# 1      099939  MASSA BISCUIT acrilex 90G - AMARELO PELE  papelaria
# 2      099935   MASSA BISCUIT acrilex 90G - VERDE MUSGO  papelaria
# 3      099993                     PINCEL TIGRE 815 - 04  papelaria
# 4      099996                     PINCEL TIGRE 815 - 10  papelaria
# ...       ...                                       ...        ...
# 5116  7100714             PANO DE COPA NATAL PAPAI NOEL    enxoval
# 5117   099804                                  TNT AZUL     tecido
# 5118   123594                    LÃ BADEN - 20 VERMELHO         la
# 5119   099599                         LÃ COLORPULL 8663         la
# 5120   099593                          LÃ MAGNUM MARROM         la
#
#       estoque_disponivel  preco             incluido_em  \
# 0                    9.0    2.5 2020-11-16 17:19:42.000
# 1                    0.0    4.5 2020-03-12 09:25:38.569
# 2                    0.0    4.5 2020-03-12 09:11:30.999
# 3                    3.0    3.5 2020-03-12 16:23:51.521
# 4                    4.0    5.0 2020-03-12 16:28:07.014
# ...                  ...    ...                     ...
# 5116                 0.0    9.5 2020-11-24 10:09:39.995
# 5117                 4.0    2.0 2020-03-07 08:19:00.682
# 5118                 4.0   22.0 2020-04-02 13:03:35.661
# 5119                 0.0   30.0 2020-03-05 09:03:44.801
# 5120                 3.0   30.0 2020-03-05 08:45:28.169
#
#                  alterado_em   ncm  taxa_depreciacao  ano_mes  ...  \
# 0    2021-04-13 15:15:27.708  3926                 0  2021-04  ...
# 1    2021-04-13 14:54:44.957  3926                 0  2021-04  ...
# 2    2021-04-13 14:55:19.701  3926                 0  2021-04  ...
# 3    2021-04-30 17:10:25.288  3926                 0  2021-04  ...
# 4    2021-04-30 17:11:11.816  3926                 0  2021-04  ...
# ...                      ...   ...               ...      ...  ...
# 5116 2022-01-15 10:33:43.065  6303                20  2022-01  ...
# 5117 2020-04-29 14:49:39.436  6303                20  2020-04  ...
# 5118 2020-04-02 13:03:35.661  6303                20  2020-04  ...
# 5119 2020-04-29 14:47:21.646  6303                20  2020-04  ...
# 5120 2020-04-20 13:20:24.581  6303                20  2020-04  ...
#
#                       clf_estoque  fator_atualizacao  depreciacao_unit  \
# 0              Produto no estoque           0.761290          0.000000
# 1     Produto não está em estoque           1.000000          0.000000
# 2     Produto não está em estoque           1.000000          0.000000
# 3              Produto no estoque           0.523590          0.000000
# 4              Produto no estoque           0.523590          0.000000
# ...                           ...                ...               ...
# 5116  Produto não está em estoque           1.000000          0.000000
# 5117           Produto no estoque           0.938286          0.053687
# 5118      Risco de estoque parado           1.000000          0.524315
# 5119  Produto não está em estoque           1.000000          0.805307
# 5120           Produto no estoque           0.946408          0.773995
#
#       fator_correcao  correcao_unit  correcao_deprec depreciacao  valor_ini  \
# 0           1.126423       2.816058         2.816058    0.000000       22.5
# 1           1.126423       5.068904         5.068904    0.000000        0.0
# 2           1.126423       5.068904         5.068904    0.000000        0.0
# 3           1.126423       3.942481         3.942481    0.000000       10.5
# 4           1.126423       5.632116         5.632116    0.000000       20.0
# ...              ...            ...              ...         ...        ...
# 5116        1.042070       9.899664         5.894360    0.000000        0.0
# 5117        1.202562       2.405123         2.351436    0.214748        8.0
# 5118        1.202562      26.456354        25.932039    2.097261       88.0
# 5119        1.202562      36.076847        35.271540    0.000000        0.0
# 5120        1.202562      36.076847        35.302852    2.321984       90.0
#
#       valor_estoque_deprec  valor_estoque_depreciado_corrigido
# 0                 0.000000                            0.000000
# 1                 0.000000                            0.000000
# 2                 0.000000                            0.000000
# 3                 0.000000                            0.000000
# 4                 0.000000                            0.000000
# ...                    ...                                 ...
# 5116              0.000000                            0.000000
# 5117              0.214748                            0.258248
# 5118              2.097261                            2.522085
# 5119              0.000000                            0.000000
# 5120              2.321984                            2.792328
#
# [5121 rows x 26 columns]

# %%
modelo_transac_prod
# Out:
#                       tipo  numero                    data  \
# 0          Ajuste de Custo   38041 2022-07-20 17:40:01.564
# 1      Ajuste de Estoque +   38040 2022-07-20 17:40:01.374
# 2          Ajuste de Custo   36992 2022-06-16 10:35:44.146
# 3      Ajuste de Estoque +   36991 2022-06-16 10:35:43.968
# 4                    Venda   36767 2022-06-09 10:42:36.640
# ...                    ...     ...                     ...
# 47447  Ajuste de Estoque +       7 2020-02-03 13:31:23.044
# 47448      Ajuste de Custo       6 2020-02-03 13:29:52.455
# 47449  Ajuste de Estoque +       5 2020-02-03 13:29:52.440
# 47450      Ajuste de Custo       4 2020-02-03 13:27:48.967
# 47451  Ajuste de Estoque +       3 2020-02-03 13:27:48.958
#
#                          hora                        produto  quant_  \
# 0     2022-07-20 17:40:01.564  LINHA CLÉA 125 -5899 PANTANAL     0.0
# 1     2022-07-20 17:40:01.374  LINHA CLÉA 125 -5899 PANTANAL    10.0
# 2     2022-06-16 10:35:44.146       AGULHA CROCHE LULI - 5,5     0.0
# 3     2022-06-16 10:35:43.968       AGULHA CROCHE LULI - 5,5    12.0
# 4     2022-06-09 10:42:36.640        PAPEL DECOUPAGE-AFQ-032    -1.0
# ...                       ...                            ...     ...
# 47447 2020-02-03 13:31:23.044            Linha Rayza - Cinza     9.0
# 47448 2020-02-03 13:29:52.455          Linha Rayza - Laranja     0.0
# 47449 2020-02-03 13:29:52.440          Linha Rayza - Laranja     5.0
# 47450 2020-02-03 13:27:48.967   Linha Rayza - Verde Bandeira     0.0
# 47451 2020-02-03 13:27:48.958   Linha Rayza - Verde Bandeira     9.0
#
#        vl__unitario  sub_total  desconto  outras_despesas gerado_clf_auto  \
# 0              9.25        0.0       0.0                0               S
# 1              0.00        0.0       0.0                0               S
# 2              3.00        0.0       0.0                0               S
# 3              0.00        0.0       0.0                0               S
# 4              3.00        3.0       0.0                0               S
# ...             ...        ...       ...              ...             ...
# 47447          0.00        0.0       0.0                0               N
# 47448          5.50        0.0       0.0                0               N
# 47449          0.00        0.0       0.0                0               N
# 47450          5.50        0.0       0.0                0               N
# 47451          0.00        0.0       0.0                0               N
#
#        total    codigo  categoria
# 0        0.0  85922412      linha
# 1        0.0  15042603      linha
# 2        0.0   3456886  armarinho
# 3        0.0  99629223  armarinho
# 4        3.0  37013810  papelaria
# ...      ...       ...        ...
# 47447    0.0     98012      linha
# 47448    0.0     98033      linha
# 47449    0.0     98033      linha
# 47450    0.0     98043      linha
# 47451    0.0     98043      linha
#
# [47452 rows x 14 columns]

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,15)
fig, ax = plt.subplots()

# We change the fontsize of minor ticks label 
ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plot_rank_categoria = modelo_inventario['categoria'].value_counts().plot(kind='bar', title='Maior número de produtos por categoria',figsize=(10,10))
plot_rank_categoria.set_xlabel('quantidade por categoria')
plot_rank_categoria.set_ylabel('Número de produtos')
plt.show()

# %%
classificacao_inv = modelo_inventario.groupby('clf_estoque').agg({'categoria': 'nunique', 'codigo': 'count'})
classificacao_inv.head()
# Out:
#                                       categoria  codigo
# clf_estoque
# Produto alterado no último trimestre         10     186
# Produto no estoque                            9    3130
# Produto não está em estoque                  12     927
# Risco de estoque parado                      10     878

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (35,10)
fig, ax = plt.subplots()

# We change the fontsize of minor ticks label 
ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

#plot by clf_estoque from tempo_em_estoque

plot_classificacao_inv = sns.barplot(x='estoque_disponivel', y='categoria', data=modelo_inventario, hue='clf_estoque')
plot_classificacao_inv.set_xlabel('Quantidade produtos no estoque')
plot_classificacao_inv.set_ylabel('Categorias')
plot_classificacao_inv.set_title('Classificação de Produtos por Estoque')
plot_classificacao_inv.legend(loc='lower right')
plt.figure(figsize=(20,20))
plt.show()

# %%
tempo_em_estoque_parado = modelo_inventario[modelo_inventario['clf_estoque'] == 'Risco de estoque parado']
agrupamento_clf = tempo_em_estoque_parado.groupby(['categoria']).agg({'codigo': 'count','preco': 'mean','estoque_disponivel': 'mean'})
agrupamento_clf
# Out:
#             codigo      preco  estoque_disponivel
# categoria
# armarinho      170   8.248882           90.878353
# artesanato      16  92.062500            1.250000
# aviamento       18   5.138889           59.472222
# enxoval         23  56.260870            2.652174
# la              18  32.600000            5.388889
# linha           47  38.385106            4.595745
# mdf            126  16.509127            5.801587
# outros           4  17.325000           18.625000
# papelaria      452   5.823230            8.265487
# tecido           4  11.825000           24.000000

# %% [markdown]
# Será considerado uma análise dos itens classificados como "Risco de estoque parado".

# %%
agrupamento_risco = modelo_inventario[modelo_inventario['clf_estoque'] == 'Risco de estoque parado'].groupby(['clf_estoque','categoria']).agg({'codigo': 'count','preco': 'mean','estoque_disponivel': 'mean','te_inicio_presente': 'mean','te_atualizacao_presente': 'mean','te_inicio_atualizacao': 'mean','fator_atualizacao': 'mean','depreciacao': 'mean'})
for index, row in agrupamento_risco.iterrows():
    agrupamento_risco = agrupamento_risco.drop(index)

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=5)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (30,10)
fig, ax = plt.subplots()

# We change the fontsize of minor ticks label 
ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

b=sns.violinplot(x = 'categoria',y='valor_estoque_depreciado_corrigido', data=modelo_inventario, hue='clf_estoque')
b.set_xlabel('Categoria')
b.set_ylabel('Valor do estoque')
b.set_title('Valor do estoque por categoria')
plt.figure(figsize=(20,20))
plot_classificacao_inv.legend(loc='upper left')
plt.show()

# %%
#Rank de produtos em estoque por categoria com risco de estarem parados
top_10_fator_atualizacao_2 = modelo_inventario[modelo_inventario['fator_atualizacao'] == 1]
top_10_fator_atualizacao_2 = top_10_fator_atualizacao_2.sort_values(by=['fator_atualizacao'], ascending=False).groupby('clf_estoque')

top_10_fator_atualizacao_2[['categoria','descricao','estoque_disponivel','te_inicio_atualizacao','fator_atualizacao']].head(50)
# Out:
#       categoria                                 descricao  estoque_disponivel  \
# 1     papelaria  MASSA BISCUIT acrilex 90G - AMARELO PELE                 0.0
# 2958      linha               BARBANTE TRENTO - CINZA 270                 0.0
# 2754  armarinho               AGULHA CROCHÊ CIRCULO - 3,5                 0.0
# 2753  armarinho                 AGULHA CROCHÊ CIRCULO - 3                 0.0
# 2745  armarinho              AGULHA CROCHÊ  MILWARD 5,5mm                 0.0
# ...         ...                                       ...                 ...
# 1746  armarinho           RENDA GUIPEARE CHL 589 VERMELHO                13.7
# 1745  armarinho           RENDA GUIPEARE CHL 589 ROSA 5CM                17.0
# 1744  armarinho              RENDA GUIPEARE CHL 589 PRETA                27.4
# 1743  armarinho            RENDA GUIPEARE CHL - 438 PRETA                13.7
# 1742  armarinho                  RENDA GUIPEARE 9CM PRETO                 3.0
#
#       te_inicio_atualizacao  fator_atualizacao
# 1                       397                1.0
# 2958                    795                1.0
# 2754                    710                1.0
# 2753                    710                1.0
# 2745                      0                1.0
# ...                     ...                ...
# 1746                      0                1.0
# 1745                      0                1.0
# 1744                      0                1.0
# 1743                      0                1.0
# 1742                      0                1.0
#
# [100 rows x 5 columns]

# %%
#g = sns.PairGrid(modelo_inventario, hue="categoria")
#g.map_diag(sns.histplot)
#g.map_offdiag(sns.scatterplot)
#g.add_legend()

# %%
#g = sns.PairGrid(modelo_inventario, hue="clf_estoque")
#g.map_diag(sns.histplot)
#g.map_offdiag(sns.scatterplot)
#g.add_legend()

# %%
#g = sns.PairGrid(modelo_inventario[modelo_inventario['clf_estoque'] == 'Risco de estoque parado'], hue='categoria')
#g.map_diag(sns.histplot)
#g.map_offdiag(sns.scatterplot)
#g.add_legend()

# %%
corr = modelo_inventario.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_85c45_row0_col0, #T_85c45_row1_col1, #T_85c45_row1_col11, #T_85c45_row2_col2, #T_85c45_row3_col3, #T_85c45_row4_col4, #T_85c45_row5_col5, #T_85c45_row5_col7, #T_85c45_row5_col10, #T_85c45_row6_col6, #T_85c45_row7_col5, #T_85c45_row7_col7, #T_85c45_row7_col10, #T_85c45_row8_col8, #T_85c45_row9_col9, #T_85c45_row10_col5, #T_85c45_row10_col7, #T_85c45_row10_col10, #T_85c45_row11_col1, #T_85c45_row11_col11, #T_85c45_row12_col12, #T_85c45_row13_col13, #T_85c45_row14_col14, #T_85c45_row15_col15, #T_85c45_row15_col16, #T_85c45_row16_col15, #T_85c45_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_85c45_row0_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_85c45_row0_col2, #T_85c45_row9_col14, #T_85c45_row13_col12, #T_85c45_row15_col8, #T_85c45_row16_col8 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_85c45_row0_col3, #T_85c45_row0_col5, #T_85c45_row0_col7 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_85c45_row0_col4, #T_85c45_row15_col13 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_85c45_row0_col6, #T_85c45_row5_col9, #T_85c45_row7_col9, #T_85c45_row9_col11, #T_85c45_row12_col14 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_85c45_row0_col8, #T_85c45_row2_col5, #T_85c45_row2_col7, #T_85c45_row2_col10, #T_85c45_row11_col15, #T_85c45_row15_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_85c45_row0_col9, #T_85c45_row3_col11, #T_85c45_row8_col11 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_85c45_row0_col10 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_85c45_row0_col11, #T_85c45_row0_col12, #T_85c45_row4_col12 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_85c45_row0_col13, #T_85c45_row14_col8, #T_85c45_row16_col11 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_85c45_row0_col14, #T_85c45_row11_col3 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_85c45_row0_col15, #T_85c45_row4_col3, #T_85c45_row11_col16, #T_85c45_row16_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_85c45_row0_col16, #T_85c45_row9_col3 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_85c45_row1_col0, #T_85c45_row3_col4, #T_85c45_row3_col5, #T_85c45_row3_col7, #T_85c45_row3_col8, #T_85c45_row3_col9, #T_85c45_row3_col10, #T_85c45_row3_col13, #T_85c45_row4_col0, #T_85c45_row4_col1, #T_85c45_row4_col11, #T_85c45_row5_col2, #T_85c45_row5_col3, #T_85c45_row6_col12, #T_85c45_row7_col2, #T_85c45_row7_col3, #T_85c45_row8_col6, #T_85c45_row8_col14, #T_85c45_row8_col15, #T_85c45_row8_col16, #T_85c45_row10_col2, #T_85c45_row10_col3, #T_85c45_row10_col6, #T_85c45_row11_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_85c45_row1_col2, #T_85c45_row5_col4, #T_85c45_row6_col16, #T_85c45_row7_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_85c45_row1_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_85c45_row1_col4, #T_85c45_row4_col14 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_85c45_row1_col5, #T_85c45_row1_col7, #T_85c45_row1_col10 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_85c45_row1_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_85c45_row1_col8 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_85c45_row1_col9, #T_85c45_row3_col2 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_85c45_row1_col12 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_85c45_row1_col13, #T_85c45_row2_col12 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_85c45_row1_col14, #T_85c45_row14_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_85c45_row1_col15, #T_85c45_row1_col16, #T_85c45_row11_col9 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_85c45_row2_col0, #T_85c45_row5_col1, #T_85c45_row7_col1, #T_85c45_row9_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_85c45_row2_col1, #T_85c45_row12_col16 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_85c45_row2_col3, #T_85c45_row4_col5, #T_85c45_row4_col7 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_85c45_row2_col4, #T_85c45_row3_col14 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_85c45_row2_col6 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_85c45_row2_col8, #T_85c45_row12_col2, #T_85c45_row14_col12, #T_85c45_row16_col1 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_85c45_row2_col9, #T_85c45_row4_col2, #T_85c45_row10_col13, #T_85c45_row14_col11 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_85c45_row2_col11, #T_85c45_row2_col13 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_85c45_row2_col14, #T_85c45_row9_col4, #T_85c45_row13_col4, #T_85c45_row15_col1 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_85c45_row2_col15, #T_85c45_row2_col16 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_85c45_row3_col0, #T_85c45_row5_col11, #T_85c45_row6_col8, #T_85c45_row7_col11, #T_85c45_row8_col0, #T_85c45_row10_col14 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_85c45_row3_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_85c45_row3_col6 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_85c45_row3_col12 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_85c45_row3_col15 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_85c45_row3_col16 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_85c45_row4_col6 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_85c45_row4_col8, #T_85c45_row9_col1 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_85c45_row4_col9 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_85c45_row4_col10 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_85c45_row4_col13 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_85c45_row4_col15, #T_85c45_row4_col16 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_85c45_row5_col0, #T_85c45_row7_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_85c45_row5_col6, #T_85c45_row7_col6, #T_85c45_row12_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_85c45_row5_col8, #T_85c45_row7_col8, #T_85c45_row10_col8 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_85c45_row5_col12, #T_85c45_row7_col12, #T_85c45_row10_col12 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_85c45_row5_col13, #T_85c45_row7_col13, #T_85c45_row13_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_85c45_row5_col14, #T_85c45_row7_col14, #T_85c45_row8_col2, #T_85c45_row10_col11 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_85c45_row5_col15, #T_85c45_row5_col16, #T_85c45_row6_col0, #T_85c45_row7_col15, #T_85c45_row7_col16, #T_85c45_row10_col15, #T_85c45_row10_col16 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_85c45_row6_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_85c45_row6_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_85c45_row6_col3 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_85c45_row6_col4 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_85c45_row6_col5, #T_85c45_row6_col7, #T_85c45_row6_col10, #T_85c45_row16_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_85c45_row6_col9, #T_85c45_row6_col13 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_85c45_row6_col11 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_85c45_row6_col14, #T_85c45_row8_col13 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_85c45_row6_col15 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_85c45_row8_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_85c45_row8_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_85c45_row8_col4, #T_85c45_row11_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_85c45_row8_col5, #T_85c45_row8_col7, #T_85c45_row8_col10 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_85c45_row8_col9, #T_85c45_row13_col14 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_85c45_row8_col12 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_85c45_row9_col2, #T_85c45_row16_col10 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_85c45_row9_col5, #T_85c45_row9_col7 {
#   background-color: #f1c

# %% [markdown]
# Devido à baixa correlação presente na massa de dados, O trabalho passa a considerar os dados de Transação de produtos para a análise do modelo.

# %% [markdown]
# ## DataFrame de Produtos

# %%
tipo_transf = modelo_transac_prod.tipo.unique()
tipo_transf
# Out:
# array(['Ajuste de Custo', 'Ajuste de Estoque +', 'Venda',
#        'Ajuste de Estoque -', 'Devolução do Cliente'], dtype=object)

# %%
modelo_transac_prod['tipo'].value_counts()
# Out:
# Venda                   19997
# Ajuste de Custo         13501
# Ajuste de Estoque +      8984
# Ajuste de Estoque -      4967
# Devolução do Cliente        3
# Name: tipo, dtype: int64

# %% [markdown]
# ### Dados de Venda

# %%
modelo_transac_prod_vendas = modelo_transac_prod[modelo_transac_prod['tipo'] == 'Venda']
modelo_transac_prod_vendas['quant_'] = modelo_transac_prod_vendas['quant_']*-1000
modelo_transac_prod_vendas
# Out:
# C:\Users\otavi\AppData\Local\Temp\ipykernel_6016\3371705807.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modelo_transac_prod_vendas['quant_'] = modelo_transac_prod_vendas['quant_']*-1000
#         tipo  numero                    data                    hora  \
# 4      Venda   36767 2022-06-09 10:42:36.640 2022-06-09 10:42:36.640
# 5      Venda   36547 2022-06-03 09:31:31.703 2022-06-03 09:31:31.703
# 6      Venda   36426 2022-05-30 16:24:04.069 2022-05-30 16:24:04.069
# 7      Venda   36392 2022-05-28 10:42:32.680 2022-05-28 10:42:32.680
# 8      Venda   36367 2022-05-27 14:08:31.247 2022-05-27 14:08:31.247
# ...      ...     ...                     ...                     ...
# 36476  Venda   11638 2020-09-13 16:46:32.133 2020-09-13 16:46:32.133
# 36477  Venda   11637 2020-09-13 16:45:49.784 2020-09-13 16:45:49.784
# 36478  Venda   11637 2020-09-13 16:45:49.784 2020-09-13 16:45:49.784
# 36479  Venda   11637 2020-09-13 16:45:49.784 2020-09-13 16:45:49.784
# 36480  Venda   11637 2020-09-13 16:45:49.784 2020-09-13 16:45:49.784
#
#                               produto  quant_  vl__unitario  sub_total  \
# 4             PAPEL DECOUPAGE-AFQ-032  1000.0           3.0        3.0
# 5                 BASTIDOR MDF - 18CM  1000.0           8.5        8.5
# 6           FRALDA BOCA NICOLI - ROSA  2000.0           4.8        9.6
# 7      AGULHA CROCHÊ ESMALTADA - 2,5M  1000.0           7.0        7.0
# 8        AGULHA CROCHÊ MILWARD 5,5 mm  1000.0           7.0        7.0
# ...                               ...     ...           ...        ...
# 36476             Linha Rayza - Lilás  2000.0           8.5       17.0
# 36477            COSTURA DRIMA - 6104  1000.0           2.0        2.0
# 36478            COSTURA DRIMA - 5878  1000.0           2.0        2.0
# 36479              COSTURA DRIMA - PT  1000.0           2.0        2.0
# 36480          COSTURA DRIMA - Branca  1000.0           2.0        2.0
#
#        desconto  outras_despesas gerado_clf_auto  total          codigo  \
# 4          0.00                0               S   3.00        37013810
# 5          0.00                0               S   8.50        32968828
# 6          0.00                0               S   9.60        30058838
# 7          0.22                0               S   6.78        18828463
# 8          0.69                0               S   6.31        98947493
# ...         ...              ...             ...    ...             ...
# 36476      0.00                0               N  17.00           98006
# 36477      0.00                0               N   2.00         7099730
# 36478      0.00                0               N   2.00  N126100-005876
# 36479      0.00                0               N   2.00          098930
# 36480      0.00                0               N   2.00   N126100-0000B
#
#        categoria
# 4      papelaria
# 5            mdf
# 6        enxoval
# 7      armarinho
# 8      armarinho
# ...          ...
# 36476      linha
# 36477      linha
# 36478      linha
# 36479      linha
# 36480      linha
#
# [19997 rows x 14 columns]

# %%
modelo_transac_prod_vendas = modelo_transac_prod_vendas.groupby(['numero','categoria','data']).agg({'quant_': 'sum','total':'sum'}).reset_index()
modelo_transac_prod_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12172 entries, 0 to 12171
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   numero     12172 non-null  int64
#  1   categoria  12172 non-null  object
#  2   data       12172 non-null  datetime64[ns]
#  3   quant_     12172 non-null  float64
#  4   total      12172 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 475.6+ KB

# %%
#modelo_transac_prod_vendas normalize quant_ field
modelo_transac_prod_vendas['qtd_norm'] = (modelo_transac_prod_vendas['quant_'] - modelo_transac_prod_vendas['quant_'].min())/ (modelo_transac_prod_vendas['quant_'].max() - modelo_transac_prod_vendas['quant_'].min())
modelo_transac_prod_vendas['data_dia'] = modelo_transac_prod_vendas['data'].dt.date

# %%
#ajustando o campo data para o formato datetime para poder fazer o agrupamento
modelo_transac_prod_vendas_diario = modelo_transac_prod_vendas[['numero','categoria','data_dia','quant_','qtd_norm','total']].sort_values(by=['data_dia'], ascending=True)

# %%
modelo_transac_prod_vendas_diario
# Out:
#        numero  categoria    data_dia    quant_  qtd_norm  total
# 0       11637      linha  2020-09-13    4000.0  0.003988   8.00
# 15      11654     tecido  2020-09-13    2000.0  0.001988  12.00
# 14      11651  armarinho  2020-09-13    4000.0  0.003988   0.80
# 12      11649  armarinho  2020-09-13    4000.0  0.003988   6.00
# 11      11648  armarinho  2020-09-13    1000.0  0.000988  10.00
# ...       ...        ...         ...       ...       ...    ...
# 12156   38237         la  2022-07-29    1000.0  0.000988   6.80
# 12170   38252  armarinho  2022-07-30  100000.0  0.099989  28.00
# 12168   38251  armarinho  2022-07-30    1000.0  0.000988   5.80
# 12169   38251      linha  2022-07-30    2000.0  0.001988   6.00
# 12171   38253     tecido  2022-07-30     250.0  0.000238   6.97
#
# [12172 rows x 6 columns]

# %%
#sns timeplot hue categoria dataframe_transacoes_produto_tratado_2 by venda and data
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (13,3)
fig, ax = plt.subplots()
#create a time plot 
for categoria in modelo_transac_prod_vendas['categoria'].unique():
    modelo_transac_prod_vendas_categoria =modelo_transac_prod_vendas_diario[modelo_transac_prod_vendas_diario['categoria'] == categoria]
    sns.lineplot(x='data_dia', y=(modelo_transac_prod_vendas_categoria['quant_']), data=modelo_transac_prod_vendas_diario)
    plt.title(categoria)
    plt.show()

# %%
modelo_transac_prod_vendas_diario_ajust = modelo_transac_prod_vendas_diario.query("categoria != 'roupas' | categoria != 'decoracao' | categoria != 'servicos' | categoria != 'outros' ")

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (13,3)
fig, ax = plt.subplots()
#create a time plot 
for categoria in modelo_transac_prod_vendas['categoria'].unique():
    modelo_transac_prod_vendas_categoria =modelo_transac_prod_vendas[modelo_transac_prod_vendas['categoria'] == categoria]
    plot_acf(modelo_transac_prod_vendas_categoria['quant_'],lags=30)
    plt.title(categoria)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA_MODEL.ipynb Célula: 33 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y136sZmlsZQ%3D%3D?line=7'>8</a> for categoria in modelo_transac_prod_vendas['categoria'].unique():
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y136sZmlsZQ%3D%3D?line=8'>9</a>     modelo_transac_prod_vendas_categoria =modelo_transac_prod_vendas[modelo_transac_prod_vendas['categoria'] == categoria]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y136sZmlsZQ%3D%3D?line=9'>10</a>     plot_acf(modelo_transac_prod_vendas_categoria['quant_'],lags=30)
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y136sZmlsZQ%3D%3D?line=10'>11</a>     plt.title(categoria)
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y136sZmlsZQ%3D%3D?line=11'>12</a>     plt.show()
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\graphics\tsaplots.py:228, in plot_acf(x, ax, lags, alpha, use_vlines, adjusted, fft, missing, title, zero, auto_ylims, bartlett_confint, vlines_kwargs, **kwargs)
#     225 if alpha is not None:
#     226     acf_x, confint = acf_x[:2]
# --> 228 _plot_corr(
#     229     ax,
#     230     title,
#     231     acf_x,
#     232     confint,
#     233     lags,
#     234     irregular,
#     235     use_vlines,
#     236     vlines_kwargs,
#     237     auto_ylims=auto_ylims,
#     238     **kwargs,
#     239 )
#     241 return fig
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\graphics\tsaplots.py:50, in _plot_corr(ax, title, acf_x, confint, lags, irregular, use_vlines, vlines_kwargs, auto_ylims, **kwargs)
#      47         confint = confint[lags]
#      49 if use_vlines:
# ---> 50     ax.vlines(lags, [0], acf_x, **vlines_kwargs)
#      51     ax.axhline(**kwargs)
#      53 kwargs.setdefault("marker", "o")
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\axes\_axes.py:1135, in Axes.vlines(self, x, ymin, ymax, colors, linestyles, label, **kwargs)
#    1133 masked_verts[:, 0, 1] = ymin
#    1134 masked_verts[:, 1, 0] = x
# -> 1135 masked_verts[:, 1, 1] = ymax
#    1137 lines = mcoll.LineCollection(masked_verts, colors=colors,
#    1138                              linestyles=linestyles, label=label)
#    1139 self.add_collection(lines, autolim=False)
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\ma\core.py:3377, in MaskedArray.__setitem__(self, indx, value)
#    3374     mval = tuple([False] * len(_dtype.names))
#    3375 if _mask is nomask:
#    3376     # Set the data, then the mask
# -> 3377     _data[indx] = dval
#    3378     if mval is not nomask:
#    3379         _mask = self._mask = make_mask_none(self.shape, _dtype)
#
# ValueError: could not broadcast input array from shape (22,) into shape (31,)

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,3)
fig, ax = plt.subplots()
#create a time plot 
for categoria in modelo_transac_prod_vendas['categoria'].unique():
    modelo_transac_prod_vendas_categoria =modelo_transac_prod_vendas_diario[modelo_transac_prod_vendas_diario['categoria'] == categoria]
    plot_acf(modelo_transac_prod_vendas_categoria['quant_'])
    plt.title(categoria)
    plt.show()
# Out:
# c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\stattools.py:681: RuntimeWarning: invalid value encountered in divide
#   acf = avf[: nlags + 1] / avf[0]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA_MODEL.ipynb Célula: 34 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y134sZmlsZQ%3D%3D?line=7'>8</a> for categoria in modelo_transac_prod_vendas['categoria'].unique():
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y134sZmlsZQ%3D%3D?line=8'>9</a>     modelo_transac_prod_vendas_categoria =modelo_transac_prod_vendas_diario[modelo_transac_prod_vendas_diario['categoria'] == categoria]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y134sZmlsZQ%3D%3D?line=9'>10</a>     plot_acf(modelo_transac_prod_vendas_categoria['quant_'])
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y134sZmlsZQ%3D%3D?line=10'>11</a>     plt.title(categoria)
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y134sZmlsZQ%3D%3D?line=11'>12</a>     plt.show()
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\graphics\tsaplots.py:216, in plot_acf(x, ax, lags, alpha, use_vlines, adjusted, fft, missing, title, zero, auto_ylims, bartlett_confint, vlines_kwargs, **kwargs)
#     214 confint = None
#     215 # acf has different return type based on alpha
# --> 216 acf_x = acf(
#     217     x,
#     218     nlags=nlags,
#     219     alpha=alpha,
#     220     fft=fft,
#     221     bartlett_confint=bartlett_confint,
#     222     adjusted=adjusted,
#     223     missing=missing,
#     224 )
#     225 if alpha is not None:
#     226     acf_x, confint = acf_x[:2]
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\stattools.py:688, in acf(x, adjusted, nlags, qstat, fft, alpha, bartlett_confint, missing)
#     686     varacf = np.ones_like(acf) / nobs
#     687     varacf[0] = 0
# --> 688     varacf[1] = 1.0 / nobs
#     689     varacf[2:] *= 1 + 2 * np.cumsum(acf[1:-1] ** 2)
#     690 else:
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
from IPython.display import display

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 15)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
from pandas.plotting import register_matplotlib_converters

register_matplotlib_converters()

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from time import time
import seaborn as sns
sns.set(style="whitegrid")

import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = np.random.seed(42)

# %% [markdown]
# ## Dados Estoque

# %%
modelo_transac_prod_estoque = modelo_transac_prod.query("tipo == 'Ajuste de Estoque +'")
modelo_transac_prod_estoque
# Out:
#                       tipo  numero                    data  \
# 1      Ajuste de Estoque +   38040 2022-07-20 17:40:01.374
# 3      Ajuste de Estoque +   36991 2022-06-16 10:35:43.968
# 13     Ajuste de Estoque +   36196 2022-05-21 12:00:33.428
# 20     Ajuste de Estoque +   35979 2022-05-17 10:46:32.297
# 22     Ajuste de Estoque +   35951 2022-05-16 13:07:22.889
# ...                    ...     ...                     ...
# 47443  Ajuste de Estoque +      11 2020-02-03 13:33:47.635
# 47445  Ajuste de Estoque +       9 2020-02-03 13:32:03.280
# 47447  Ajuste de Estoque +       7 2020-02-03 13:31:23.044
# 47449  Ajuste de Estoque +       5 2020-02-03 13:29:52.440
# 47451  Ajuste de Estoque +       3 2020-02-03 13:27:48.958
#
#                          hora                               produto  quant_  \
# 1     2022-07-20 17:40:01.374         LINHA CLÉA 125 -5899 PANTANAL    10.0
# 3     2022-06-16 10:35:43.968              AGULHA CROCHE LULI - 5,5    12.0
# 13    2022-05-21 12:00:33.428  CACHECOL GOLA LÃ ONDA CIDINHA BORGES     1.0
# 20    2022-05-17 10:46:32.297                      TOUCA TRICO ROSA     1.0
# 22    2022-05-16 13:07:22.889        TOALHA LAVABO PINTADA C/ RENDA     2.0
# ...                       ...                                   ...     ...
# 47443 2020-02-03 13:33:47.635           Linha Rayza - Branco Optico    31.0
# 47445 2020-02-03 13:32:03.280                 Linha Rayza - Cenoura    10.0
# 47447 2020-02-03 13:31:23.044                   Linha Rayza - Cinza     9.0
# 47449 2020-02-03 13:29:52.440                 Linha Rayza - Laranja     5.0
# 47451 2020-02-03 13:27:48.958          Linha Rayza - Verde Bandeira     9.0
#
#        vl__unitario  sub_total  desconto  outras_despesas gerado_clf_auto  \
# 1               0.0        0.0       0.0                0               S
# 3               0.0        0.0       0.0                0               S
# 13              0.0        0.0       0.0                0               S
# 20              0.0        0.0       0.0                0               S
# 22              0.0        0.0       0.0                0               S
# ...             ...        ...       ...              ...             ...
# 47443           0.0        0.0       0.0                0               N
# 47445           0.0        0.0       0.0                0               N
# 47447           0.0        0.0       0.0                0               N
# 47449           0.0        0.0       0.0                0               N
# 47451           0.0        0.0       0.0                0               N
#
#        total    codigo  categoria
# 1        0.0  15042603      linha
# 3        0.0  99629223  armarinho
# 13       0.0  11768732         la
# 20       0.0  31327216  armarinho
# 22       0.0  80901586    enxoval
# ...      ...       ...        ...
# 47443    0.0     98001      linha
# 47445    0.0     98021      linha
# 47447    0.0     98012      linha
# 47449    0.0     98033      linha
# 47451    0.0     98043      linha
#
# [8984 rows x 14 columns]

# %%
modelo_transac_prod_estoque = modelo_transac_prod_estoque.groupby(['numero','categoria','data']).agg({'quant_': 'sum','total':'sum'}).reset_index()
modelo_transac_prod_estoque.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8924 entries, 0 to 8923
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   numero     8924 non-null   int64
#  1   categoria  8924 non-null   object
#  2   data       8924 non-null   datetime64[ns]
#  3   quant_     8924 non-null   float64
#  4   total      8924 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 348.7+ KB

# %%
#modelo_transac_prod_vendas normalize quant_ field
modelo_transac_prod_estoque['qtd_norm'] = (modelo_transac_prod_estoque['quant_'] - modelo_transac_prod_estoque['quant_'].min())/ (modelo_transac_prod_estoque['quant_'].max() - modelo_transac_prod_estoque['quant_'].min())
modelo_transac_prod_estoque['data_dia'] = modelo_transac_prod_estoque['data'].dt.date

# %%
#ajustando o campo data para o formato datetime para poder fazer o agrupamento
modelo_transac_prod_estoque_diario = modelo_transac_prod_estoque[['numero','categoria','data_dia','quant_','qtd_norm','total']]

# %%
modelo_transac_prod_estoque_diario
# Out:
#       numero  categoria    data_dia  quant_  qtd_norm  total
# 0          1      linha  2020-02-03     1.0  0.000064    0.0
# 1          3      linha  2020-02-03     9.0  0.000732    0.0
# 2          5      linha  2020-02-03     5.0  0.000398    0.0
# 3          7      linha  2020-02-03     9.0  0.000732    0.0
# 4          9      linha  2020-02-03    10.0  0.000815    0.0
# ...      ...        ...         ...     ...       ...    ...
# 8919   38219  armarinho  2022-07-28     1.0  0.000064    0.0
# 8920   38220  armarinho  2022-07-28     1.0  0.000064    0.0
# 8921   38226        mdf  2022-07-29     1.0  0.000064    0.0
# 8922   38232     outros  2022-07-29     1.0  0.000064    0.0
# 8923   38235     outros  2022-07-29     1.0  0.000064    0.0
#
# [8924 rows x 6 columns]

# %%
#sns timeplot hue categoria dataframe_transacoes_produto_tratado_2 by venda and data
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (13,3)
fig, ax = plt.subplots()
#create a time plot 
for categoria in modelo_transac_prod_estoque['categoria'].unique():
    modelo_transac_prod_estoque_categoria =modelo_transac_prod_estoque_diario[modelo_transac_prod_estoque_diario['categoria'] == categoria]
    sns.lineplot(x='data_dia', y=(modelo_transac_prod_estoque_categoria['quant_']), data=modelo_transac_prod_estoque_diario)
    plt.title(categoria)
    plt.show()

# %% [markdown]
# Por conta da falta da presença de registros das entradas de produtos, que não condizem com a sua variação em venda(i.e. saída de produtos do inventário), nos dá um material de hipótese na qual há mais estoque do que aquilo presente em sistema de produtos. Um exmeplo disso, são os dados de estocagem de itens da classificação como de roupas ou decoração. Portanto, desconsideraremos essas categorias da massa usada para o modelo. Além disso, por conta da falta de registros em estoque, consideraremos a premissa de que o modelo será uma análise preditiva futura de necessidade de estoque devolvendo, um valor mínimo de demanda, na qual o estoque a ser feito possa suprí-lo considerando as demais variáveis de oferta e demanda do mercado de distribuidores dos materiais ofertados por esse ponto de venda estudado. Desta maneira, consideremos como a quantidade de vendas como a saída de produtos no estoque. Isso foi invertido a valor positivo para que facilite a análise.

# %%
modelo_transac_prod_vendas_diario_ajust = modelo_transac_prod_vendas_diario.query('categoria != "servicos" & categoria != "roupas" & categoria != "decoracao"')
modelo_transac_prod_vendas_diario_ajust = modelo_transac_prod_vendas_diario_ajust.sort_values(by=['data_dia'])

# %%
#dickey  fuller test
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
        
        #Determing rolling statistics
        rolmean = timeseries.rolling(12).mean()
        rolstd = timeseries.rolling(12).std()
    
        #Plot rolling statistics:
        orig = plt.plot(timeseries, color='brown',label='Original')
        mean = plt.plot(rolmean, color='blue', label='Média móvel')
        std = plt.plot(rolstd, color='green', label = 'Desvio padrão móvel')
        plt.legend(loc='best')
        plt.title('Média móvel e desvio padrão')
        plt.show(block=False)
    
        #Perform Dickey-Fuller test:
        print ('Results of Dickey-Fuller Test:')
        dftest = adfuller(timeseries, autolag='t-stat')
        dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
        for key,value in dftest[4].items():
            dfoutput['Critical Value (%s)'%key] = value
        print (dfoutput)

# %%
modelo_transac_prod_vendas_diario_ajust.sort_values(by=['data_dia'])
# Out:
#        numero  categoria    data_dia  quant_  qtd_norm  total
# 0       11637      linha  2020-09-13    4.00  0.003988   8.00
# 7       11644      linha  2020-09-13    1.00  0.000988  16.50
# 1       11638      linha  2020-09-13    2.00  0.001988  17.00
# 3       11640      linha  2020-09-13    4.00  0.003988  34.00
# 4       11641      linha  2020-09-13    1.00  0.000988  12.90
# ...       ...        ...         ...     ...       ...    ...
# 12154   38236  armarinho  2022-07-29    6.00  0.005988   6.00
# 12169   38251      linha  2022-07-30    2.00  0.001988   6.00
# 12170   38252  armarinho  2022-07-30  100.00  0.099989  28.00
# 12168   38251  armarinho  2022-07-30    1.00  0.000988   5.80
# 12171   38253     tecido  2022-07-30    0.25  0.000238   6.97
#
# [12154 rows x 6 columns]

# %%
for categoria in modelo_transac_prod_vendas_diario_ajust['categoria'].unique():
    modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas_diario_ajust[modelo_transac_prod_vendas_diario['categoria'] == categoria]
    print('categoria:{0}'.format(categoria))
    test_stationarity(modelo_transac_prod_vendas_categoria['quant_'])
# Out:
# categoria:linha
# C:\Users\otavi\AppData\Local\Temp\ipykernel_6016\76374108.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas_diario_ajust[modelo_transac_prod_vendas_diario['categoria'] == categoria]
# Results of Dickey-Fuller Test:
# Test Statistic                -1.043567e+01
# p-value                        1.568822e-18
# #Lags Used                     3.000000e+01
# Number of Observations Used    4.109000e+03
# Critical Value (1%)           -3.431942e+00
# Critical Value (5%)           -2.862244e+00
# Critical Value (10%)          -2.567145e+00
# dtype: float64
# categoria:tecido
# C:\Users\otavi\AppData\Local\Temp\ipykernel_6016\76374108.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas_diario_ajust[modelo_transac_prod_vendas_diario['categoria'] == categoria]
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.157546
# p-value                          0.022577
# #Lags Used                      11.000000
# Number of Observations Used    251.000000
# Critical Value (1%)             -3.456674
# Critical Value (5%)             -2.873125
# Critical Value (10%)            -2.572944
# dtype: float64
# categoria:armarinho
# C:\Users\otavi\AppData\Local\Temp\ipykernel_6016\76374108.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas_diario_ajust[modelo_transac_prod_vendas_diario['categoria'] == categoria]
# Results of Dickey-Fuller Test:
# Test Statistic                -1.182071e+01
# p-value                        8.427670e-22
# #Lags Used                     1.700000e+01
# Number of Observations Used    3.760000e+03
# Critical Value (1%)           -3.432090e+00
# Critical Value (5%)           -2.862309e+00
# Critical Value (10%)          -2.567179e+00
# dtype: float64
# categoria:papelaria
# C:\Users\otavi\AppData\Local\Temp\ipykernel_6016\76374108.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas_diario_ajust[modelo_transac_prod_vendas_diario['categoria'] == categoria]
# Results of Dickey-Fuller Test:
# Test Statistic                   -4.927119
# p-value                           0.000031
# #Lags Used                       21.000000
# Number of Observations Used    1520.000000
# Critical Value (1%)              -3.434659
# Critical Value (5%)              -2.863443
# Critical Value (10%)             -2.567783
# dtype: float64
# categoria:artesanato
# C:\Users\otavi\AppData\Local\Temp\ipykernel_6016\76374108.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas_diario_ajust[modelo_transac_prod_vendas_diario['categoria'] == categoria]
# Results of Dickey-Fuller Test:
# Test Statistic                -6.157494e+00
# p-value                        7.308417e-08
# #Lags Used                     2.000000e+00
# Number of Observations Used    1.530000e+02
# Critical Value (1%)           -3.473830e+00
# Critical Value (5%)           -2.880623e+00
# Critical Value (10%)          -2.576945e+00
# dtype: float64
# categoria:mdf
# C:\Users\otavi\AppData\Local\Temp\ipykernel_6016\76374108.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas_diario_ajust[modelo_transac_prod_vendas_diario['categoria'] == categoria]
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.759926
# p-value                          0.003345
# #Lags Used                      16.000000
# Number of Observations Used    281.000000
# Critical Value (1%)             -3.453838
# Critical Value (5%)             -2.871881
# Critical Value (10%)            -2.572280
# dtype: float64
# categoria:enxoval
# C:\Users\otavi\AppData\Local\Temp\ipykernel_6016\76374108.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas_diario_ajust[modelo_transac_prod_vendas_diario['categoria'] == categoria]
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.488608
# p-value                          0.008285
# #Lags Used                      15.000000
# Number of Observations Used    445.000000
# Critical Value (1%)             -3.445131
# Critical Value (5%)             -2.868057
# Critical Value (10%)            -2.570241
# dtype: float64
# categoria:la
# C:\Users\otavi\AppData\Local\Temp\ipykernel_6016\76374108.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas_diario_ajust[modelo_transac_prod_vendas_diario['categoria'] == categoria]
# C:\Users\otavi\AppData\Local\Temp\ipykernel_6016\76374108.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas_diario_ajust[modelo_transac_prod_vendas_diario['categoria'] == categoria]
# Results of Dickey-Fuller Test:
# Test Statistic                -1.353904e+01
# p-value                        2.534244e-25
# #Lags Used                     5.000000e+00
# Number of Observations Used    1.469000e+03
# Critical Value (1%)           -3.434809e+00
# Critical Value (5%)           -2.863510e+00
# Critical Value (10%)          -2.567819e+00
# dtype: float64
# categoria:aviamento
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.364196
# p-value                         0.152098
# #Lags Used                      6.000000
# Number of Observations Used    15.000000
# Critical Value (1%)            -3.964443
# Critical Value (5%)            -3.084908
# Critical Value (10%)           -2.681814
# dtype: float64
# categoria:outros
# C:\Users\otavi\AppData\Local\Temp\ipykernel_6016\76374108.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas_diario_ajust[modelo_transac_prod_vendas_diario['categoria'] == categoria]
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.912964
# p-value                         0.001941
# #Lags Used                      0.000000
# Number of Observations Used    18.000000
# Critical Value (1%)            -3.859073
# Critical Value (5%)            -3.042046
# Critical Value (10%)           -2.660906
# dtype: float64

# %%
## Com isso removeremos a sazonalidade e a tendência dos dados, para que possamos aplicar o modelo ARIMA.

#Removendo a sazonalidade e a tendência dos dados

# %%
## Com isso removeremos a sazonalidade e a tendência dos dados, para que possamos aplicar o modelo ARIMA.

#Removendo a sazonalidade e a tendência dos dados

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse


# Multiplicative Decomposition 
#multiplicative_decomposition = seasonal_decompose(dataframe_transacoes_produto_tratado_2['quant_'], model='multiplicative', period=30)
for categoria in modelo_transac_prod_vendas['categoria'].unique():
    modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas[modelo_transac_prod_vendas['categoria'] == categoria]
    print('categoria:{0}'.format(categoria))
# Additive Decomposition
    additive_decomposition = seasonal_decompose(modelo_transac_prod_vendas_categoria['quant_'], model='additive', period=60)
# Multiplicative Decomposition
    multiplicative_decomposition = seasonal_decompose(modelo_transac_prod_vendas_categoria['quant_'], model='multiplicative', period=30)
# Plot
    plt.rcParams.update({'figure.figsize': (16,12)})
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])

    additive_decomposition.plot().suptitle('Additive Decomposition', fontsize=16)
    multiplicative_decomposition.plot().suptitle('Multiplicative Decomposition', fontsize=16)

    plt.tight_layout(rect=[0, 0.03, 1, 0.95])

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA_MODEL.ipynb Célula: 35 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X46sZmlsZQ%3D%3D?line=1'>2</a> from dateutil.parser import parse
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X46sZmlsZQ%3D%3D?line=4'>5</a> # Multiplicative Decomposition
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X46sZmlsZQ%3D%3D?line=5'>6</a> #multiplicative_decomposition = seasonal_decompose(dataframe_transacoes_produto_tratado_2['quant_'], model='multiplicative', period=30)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X46sZmlsZQ%3D%3D?line=6'>7</a> for categoria in modelo_transac_prod_vendas['categoria'].unique():
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X46sZmlsZQ%3D%3D?line=7'>8</a>     modelo_transac_prod_vendas_categoria = modelo_transac_prod_vendas[modelo_transac_prod_vendas['categoria'] == categoria]
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X46sZmlsZQ%3D%3D?line=8'>9</a>     print('categoria:{0}'.format(categoria))
#
# NameError: name 'modelo_transac_prod_vendas' is not defined

# %%
import statsmodels.api as sm
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.arima.model import ARIMAResults
from statsmodels.tsa.arima.model import ARIMAResultsWrapper



data1 = modelo_transac_prod_vendas_1.query('categoria == "enxoval"')
data = data1['quant_']
out = 'AIC: {0:0.3f}, HQIC: {1:0.3f}, BIC: {2:0.3f}'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA_MODEL.ipynb Célula: 47 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X62sZmlsZQ%3D%3D?line=3'>4</a> from statsmodels.tsa.arima.model import ARIMAResults
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X62sZmlsZQ%3D%3D?line=4'>5</a> from statsmodels.tsa.arima.model import ARIMAResultsWrapper
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X62sZmlsZQ%3D%3D?line=8'>9</a> data1 = modelo_transac_prod_vendas_1.query('categoria == "enxoval"')
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X62sZmlsZQ%3D%3D?line=9'>10</a> data = data1['quant_']
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X62sZmlsZQ%3D%3D?line=10'>11</a> out = 'AIC: {0:0.3f}, HQIC: {1:0.3f}, BIC: {2:0.3f}'
#
# NameError: name 'modelo_transac_prod_vendas_1' is not defined

# %%
res = AutoReg(data, lags = [1, 11, 12]).fit()


res.summary()
# Out:
# c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                 quant_   No. Observations:                  461
# Model:             Restr. AutoReg(12)   Log Likelihood                -920.669
# Method:               Conditional MLE   S.D. of innovations              1.881
# Date:                Mon, 26 Sep 2022   AIC                           1851.339
# Time:                        22:29:52   BIC                           1871.874
# Sample:                            12   HQIC                          1859.433
#                                   461
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.7031      0.181      9.406      0.000       1.348       2.058
# quant_.L1      0.0705      0.050      1.412      0.158      -0.027       0.168
# quant_.L11     0.1173      0.051      2.307      0.021       0.018       0.217
# quant_.L12    -0.0344      0.051     -0.673      0.501      -0.135       0.066
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1            -1.1449           -0.3304j            1.1916           -0.4553
# AR.2            -1.1449           +0.3304j            1.1916            0.4553
# AR.3            -0.7953           -0.8930j            1.1958           -0.3658
# AR.4            -0.7953           +0.8930j            1.1958            0.3658
# AR.5            -0.1971           -1.1889j            1.2051           -0.2761
# AR.6            -0.1971           +1.1889j            1.2051            0.2761
# AR.7             0.4782           -1.1232j            1.2208           -0.1859
# AR.8             0.4782           +1.1232j            1.2208            0.1859
# AR.9             1.0309           -0.6936j            1.2425           -0.0943
# AR.10            1.0309           +0.6936j            1.2425            0.0943
# AR.11            1.2563           -0.0000j            1.2563           -0.0000
# AR.12            3.4067           -0.0000j            3.4067           -0.0000
# ------------------------------------------------------------------------------
# """

# %%
plot_res = res.plot_diagnostics(figsize=(15, 12))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA_MODEL.ipynb Célula: 39 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> plot_res = res.plot_diagnostics(figsize=(15, 12))
#
# NameError: name 'res' is not defined

# %%
res.plot_predict(dynamic=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA_MODEL.ipynb Célula: 40 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X54sZmlsZQ%3D%3D?line=0'>1</a> res.plot_predict(dynamic=False)
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X54sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# NameError: name 'res' is not defined

# %%
res_2 = ARIMA(data, order=(1, 1, 2)).fit()

print(out.format(res_2.aic, res_2.hqic, res_2.bic))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA_MODEL.ipynb Célula: 41 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> res_2 = ARIMA(data, order=(1, 1, 2)).fit()
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X55sZmlsZQ%3D%3D?line=2'>3</a> print(out.format(res_2.aic, res_2.hqic, res_2.bic))
#
# NameError: name 'data' is not defined

# %%
res_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 quant_   No. Observations:                  461
# Model:                 ARIMA(1, 1, 2)   Log Likelihood                -944.241
# Date:                Mon, 26 Sep 2022   AIC                           1896.482
# Time:                        23:05:49   BIC                           1913.007
# Sample:                             0   HQIC                          1902.989
#                                 - 461
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9437      0.134     -7.017      0.000      -1.207      -0.680
# ma.L1          0.0044      0.121      0.037      0.971      -0.233       0.241
# ma.L2         -0.9201      0.115     -7.974      0.000      -1.146      -0.694
# sigma2         3.5329      0.093     38.141      0.000       3.351       3.714
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              3223.02
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.39   Skew:                             2.92
# Prob(H) (two-sided):                  0.04   Kurtosis:                        14.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
plot = res_2.plot_diagnostics(figsize=(15, 12))

# %%
res_2.plot_predict(dynamic=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA_MODEL.ipynb Célula: 44 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y114sZmlsZQ%3D%3D?line=0'>1</a> res_2.plot_predict(dynamic=False)
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y114sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\base\wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      31 except AttributeError:
#      32     pass
# ---> 34 obj = getattr(results, attr)
#      35 data = results.model.data
#      36 how = self._wrap_attrs.get(attr)
#
# AttributeError: 'ARIMAResults' object has no attribute 'plot_predict'

# %%
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.tsa.arima.model import ARIMAResults
from statsmodels.tsa.arima.model import ARIMAResultsWrapper
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA

# %%
corr = modelo_transac_prod_vendas.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6cedc_row0_col0, #T_6cedc_row1_col1, #T_6cedc_row1_col3, #T_6cedc_row2_col2, #T_6cedc_row3_col1, #T_6cedc_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6cedc_row0_col1, #T_6cedc_row0_col2, #T_6cedc_row0_col3, #T_6cedc_row1_col0, #T_6cedc_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6cedc_row1_col2, #T_6cedc_row3_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_6cedc_row2_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_6cedc_row2_col1, #T_6cedc_row2_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6cedc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6cedc_level0_col0" class="col_heading level0 col0" >numero</th>
#       <th id="T_6cedc_level0_col1" class="col_heading level0 col1" >quant_</th>
#       <th id="T_6cedc_level0_col2" class="col_heading level0 col2" >total</th>
#       <th id="T_6cedc_level0_col3" class="col_heading level0 col3" >qtd_norm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cedc_level0_row0" class="row_heading level0 row0" >numero</th>
#       <td id="T_6cedc_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6cedc_row0_col1" class="data row0 col1" >0.018983</td>
#       <td id="T_6cedc_row0_col2" class="data row0 col2" >0.023482</td>
#       <td id="T_6cedc_row0_col3" class="data row0 col3" >0.018983</td>
#     </tr>
#     <tr>
#       <th id="T_6cedc_level0_row1" class="row_heading level0 row1" >quant_</th>
#       <td id="T_6cedc_row1_col0" class="data row1 col0" >0.018983</td>
#       <td id="T_6cedc_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6cedc_row1_col2" class="data row1 col2" >0.090436</td>
#       <td id="T_6cedc_row1_col3" class="data row1 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6cedc_level0_row2" class="row_heading level0 row2" >total</th>
#       <td id="T_6cedc_row2_col0" class="data row2 col0" >0.023482</td>
#       <td id="T_6cedc_row2_col1" class="data row2 col1" >0.090436</td>
#       <td id="T_6cedc_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_6cedc_row2_col3" class="data row2 col3" >0.090436</td>
#     </tr>
#     <tr>
#       <th id="T_6cedc_level0_row3" class="row_heading level0 row3" >qtd_norm</th>
#       <td id="T_6cedc_row3_col0" class="data row3 col0" >0.018983</td>
#       <td id="T_6cedc_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_6cedc_row3_col2" class="data row3 col2" >0.090436</td>
#       <td id="T_6cedc_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
modelo_transac_prod_vendas_1 = modelo_transac_prod_vendas[['numero','categoria','data_dia','quant_','qtd_norm','total']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA_MODEL.ipynb Célula: 47 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#X64sZmlsZQ%3D%3D?line=0'>1</a> modelo_transac_prod_vendas_1 = modelo_transac_prod_vendas[['numero','categoria','data_dia','quant_','qtd_norm','total']]
#
# NameError: name 'modelo_transac_prod_vendas' is not defined

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot

plot_acf(modelo_transac_prod_vendas_1.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA_MODEL.ipynb Célula: 48 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y114sZmlsZQ%3D%3D?line=1'>2</a> from statsmodels.graphics.tsaplots import plot_pacf
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y114sZmlsZQ%3D%3D?line=2'>3</a> from matplotlib import pyplot
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA_MODEL.ipynb#Y114sZmlsZQ%3D%3D?line=4'>5</a> plot_acf(modelo_transac_prod_vendas_1.values)
#
# NameError: name 'modelo_transac_prod_vendas_1' is not defined

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import Binarizer
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import LabelEncoder

ARIMA method for time series forecasting
    
    from statsmodels.tsa.arima_model import ARIMA
    from sklearn.metrics import mean_squared_error
    from math import sqrt
    from sklearn.metrics import mean_absolute_error
    from sklearn.metrics import mean_squared_error
    from sklearn.metrics import r2_score
    from sklearn.metrics import mean_absolute_percentage_error
    from sklearn.metrics import median_absolute_error
    from sklearn.metrics import max_error
    from sklearn.metrics import explained_variance_score
    from sklearn.metrics import mean_poisson_deviance
    from sklearn.metrics import mean_gamma_deviance
    from sklearn.metrics import mean_tweedie_deviance
    from sklearn.metrics import mean_absolute_percentage_error
    from sklearn.metrics import median_absolute_error
    from sklearn.metrics import max_error
    from sklearn.metrics import explained_variance_score
    from sklearn.metrics import mean_poisson_deviance
    from sklearn.metrics import mean_gamma_deviance
    from sklearn.metrics import mean_tweedie_deviance
    from sklearn.metrics import mean_absolute_percentage_error
    from sklearn.metrics import median_absolute_error
    from sklearn.metrics import max_error
    from sklearn.metrics import explained_variance_score
    from sklearn.metrics import mean_poisson_deviance
    from sklearn.metrics import mean_gamma_deviance
    from sklearn.metrics import mean_tweedie_deviance
    from sklearn.metrics import mean_absolute_percentage_error
    from sklearn.metrics import median_absolute_error
    from sklearn.metrics import max_error
    from sklearn.metrics import explained_variance_score
    from sklearn.metrics import mean_poisson_deviance
    from sklearn.metrics import mean_gamma_deviance
    from sklearn.metrics import mean_tweedie_deviance
    from sklearn.metrics import mean_absolute_percentage_error
    from sklearn.metrics import median_absolute_error
    from sklearn.metrics import max_error
    from sklearn.metrics import explained_variance_score
    from sklearn.metrics import mean_poisson_deviance
    from sklearn.metrics import mean_gamma_deviance
    from sklearn.metrics import mean_tweedie_deviance
    from sklearn.metrics import mean_absolute_percentage_error
    from sklearn.metrics import median_absolute_error
    from sklearn.metrics import max_error
    from sklearn.metrics import explained_variance_score
    from sklearn.metrics import mean_poisson_deviance
    from sklearn.metrics import mean_gamma_deviance
    from sklearn.metrics import mean_tweedie_deviance
    from sklearn.metrics import mean_absolute_percentage_error
    from sklearn.metrics import median_absolute_error
    from sklearn.metrics import max_error
    from sklearn.metrics import explained_variance_score
    from sklearn.metrics import mean_poisson_deviance
    from sklearn.metrics import mean_gamma_deviance
    from sklearn.metrics import mean_tweedie_deviance
    from sklearn.metrics import mean_absolute_percentage_error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA.ipynb Célula: 33 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> arima = ARIMA(modelo_transac_prod, order=(1, 1, 1))
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> arima_fit = arima.fit()
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> print(arima_fit.summary())
#
# NameError: name 'ARIMA' is not defined

# %%
g = sns.PairGrid(dataframe_transacoes_produto_tratado[dataframe_transacoes_produto_tratado['tipo'] == 'Ajuste de Estoque +'],hue='tipo')
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot, lw=3, legend=False)

# %%
g = sns.PairGrid(dataframe_transacoes_produto_tratado[dataframe_transacoes_produto_tratado['tipo'] == 'Ajuste de Estoque -'],hue='tipo')
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot, lw=3, legend=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

# %%
# Plot
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(10,6))
for categoria in dataframe_transacoes_produto_tratado_2['categoria'].unique():
    for i, ax in enumerate(axes.flatten()):
        data = dataframe_transacoes_produto_tratado_2[dataframe_transacoes_produto_tratado_2.columns[i]]
        ax.plot(data, color='blue', linewidth=1)
        # Decorations
        ax.set_title(dataframe_transacoes_produto_tratado_2.columns[i])
        ax.xaxis.set_ticks_position('none')
        ax.yaxis.set_ticks_position('none')
        ax.spines["top"].set_alpha(0)
        ax.tick_params(labelsize=6)

plt.tight_layout()

# %% [markdown]
# Testing Causation using Granger’s Causality Test
# The basis behind Vector AutoRegression is that each of the time series in the system influences each other. That is, you can predict the series with past values of itself along with other series in the system.
#
# Using Granger’s Causality Test, it’s possible to test this relationship before even building the model.
#
# So what does Granger’s Causality really test?
#
# Granger’s causality tests the null hypothesis that the coefficients of past values in the regression equation is zero.
#
# In simpler terms, the past values of time series (X) do not cause the other series (Y). So, if the p-value obtained from the test is lesser than the significance level of 0.05, then, you can safely reject the null hypothesis.
#
# The below code implements the Granger’s Causality test for all possible combinations of the time series in a given dataframe and stores the p-values of each combination in the output matrix.

# %%
from statsmodels.tsa.stattools import grangercausalitytests
maxlag=12
test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

grangers_causation_matrix(dataframe_transacoes_produto_tratado_2, variables = df.columns)
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA.ipynb Célula: 117 in <cell line: 26>()
#
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y226sZmlsZQ%3D%3D?line=22'>23</a>     df.index = [var + '_y' for var in variables]
#
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y226sZmlsZQ%3D%3D?line=23'>24</a>     return df
#
# ---> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y226sZmlsZQ%3D%3D?line=25'>26</a> grangers_causation_matrix(dataframe_transacoes_produto_tratado_2, variables = df.columns)
#
#
#
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA.ipynb Célula: 117 in grangers_causation_matrix(data, variables, test, verbose)
#
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y226sZmlsZQ%3D%3D?line=14'>15</a> for c in df.columns:
#
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y226sZmlsZQ%3D%3D?line=15'>16</a>     for r in df.index:
#
# ---> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y226sZmlsZQ%3D%3D?line=16'>17</a>         test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
#
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y226sZmlsZQ%3D%3D?line=17'>18</a>         p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
#
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y226sZmlsZQ%3D%3D?line=18'>19</a>         if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
#
#
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\stattools.py:1457, in grangercausalitytests(x, maxlag, addconst, verbose)
#
#    1388 def grangercausalitytests(x, maxlag, addconst=True, verbose=True):
#
#    1389     """
#
#    1390     Four tests for granger non causality of 2 time series.
#
#    1391
#
#    (...)
#
#    1455     >>> gc_res = grangercausalitytests(data, [4])
#
#    1456     """
#
# -> 1457     x = array_like(x, "x", ndim=2)
#
#    1458     if not np.isfinite(x).all():
#
#    1459         raise ValueError("x contains NaN or inf values.")
#
#
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tools\validation\validation.py:135, in array_like(obj, name, dtype, ndim, maxdim, shape, order, contiguous, optional)
#
#     133 if optional and obj is None:
#
#     134     return None
#
# --> 135 arr = np.asarray(obj, dtype=dtype, order=order)
#
#     136 if maxdim is not None:
#
#     137     if arr.ndim > maxdim:
#
#
#
# File c:\Users\otavi\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py:2064, in NDFrame.__array__(self, dtype)
#
#    2063 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#
# -> 2064     return np.asarray(self._values, dtype=dtype)
#
#
#
# ValueError: could not convert string to float: 'tecido'

# %% [markdown]
# So how to read the above output?
#
# The row are the Response (Y) and the columns are the predictor series (X).
# For example, if you take the value 0.0003 in (row 1, column 2), it refers to the p-value of pgnp_x causing rgnp_y. Whereas, the 0.000 in (row 2, column 1) refers to the p-value of rgnp_y causing pgnp_x.
#
# So, how to interpret the p-values?
#
# If a given p-value is < significance level (0.05), then, the corresponding X series (column) causes the Y (row).
#
# For example, P-Value of 0.0003 at (row 1, column 2) represents the p-value of the Grangers Causality test for pgnp_x causing rgnp_y, which is less that the significance level of 0.05.
#
# So, you can reject the null hypothesis and conclude pgnp_x causes rgnp_y.
#
# Looking at the P-Values in the above table, you can pretty much observe that all the variables (time series) in the system are interchangeably causing each other.
#
# This makes this system of multi time series a good candidate for using VAR models to forecast.
#
# Next, let’s do the Cointegration test.

# %% [markdown]
# . Cointegration Test
# Cointegration test helps to establish the presence of a statistically significant connection between two or more time series.
#
# But, what does Cointegration mean?
# To understand that, you first need to know what is ‘order of integration’ (d).
#
# Order of integration(d) is nothing but the number of differencing required to make a non-stationary time series stationary.
#
# Now, when you have two or more time series, and there exists a linear combination of them that has an order of integration (d) less than that of the individual series, then the collection of series is said to be cointegrated.
#
# Ok?
#
# When two or more time series are cointegrated, it means they have a long run, statistically significant relationship.
#
# This is the basic premise on which Vector Autoregression(VAR) models is based on. So, it’s fairly common to implement the cointegration test before starting to build VAR models.
#
# Alright, So how to do this test?
#
# Soren Johanssen in his paper (1991) devised a procedure to implement the cointegration test.
#
# It is fairly straightforward to implement in python’s statsmodels, as you can see below.

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def cointegration_test(df, alpha=0.05): 
    """Perform Johanson's Cointegration Test and Report Summary"""
    out = coint_johansen(df,-1,5)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
    def adjust(val, length= 6): return str(val).ljust(length)

    # Summary
    print('Name   ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

cointegration_test(df)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA.ipynb Célula: 120 in <cell line: 16>()
#
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y235sZmlsZQ%3D%3D?line=12'>13</a>     for col, trace, cvt in zip(df.columns, traces, cvts):
#
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y235sZmlsZQ%3D%3D?line=13'>14</a>         print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)
#
# ---> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y235sZmlsZQ%3D%3D?line=15'>16</a> cointegration_test(df)
#
#
#
# NameError: name 'df' is not defined

# %% [markdown]
# Split the Series into Training and Testing Data
# Splitting the dataset into training and test data.
#
# The VAR model will be fitted on df_train and then used to forecast the next 4 observations. These forecasts will be compared against the actuals present in test data.
#
# To do the comparisons, we will use multiple forecast accuracy metrics, as seen later in this article.

# %%
nobs = 4
df_train, df_test = df[0:-nobs], df[-nobs:]

# Check size
print(df_train.shape)  # (119, 8)
print(df_test.shape)  # (4, 8)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# c:\Users\otavi\codes\Parser_ETL\Analysis\EDA.ipynb Célula: 122 in <cell line: 2>()
#
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y243sZmlsZQ%3D%3D?line=0'>1</a> nobs = 4
#
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y243sZmlsZQ%3D%3D?line=1'>2</a> df_train, df_test = df[0:-nobs], df[-nobs:]
#
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y243sZmlsZQ%3D%3D?line=3'>4</a> # Check size
#
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/codes/Parser_ETL/Analysis/EDA.ipynb#Y243sZmlsZQ%3D%3D?line=4'>5</a> print(df_train.shape)  # (119, 8)
#
#
#
# NameError: name 'df' is not defined
